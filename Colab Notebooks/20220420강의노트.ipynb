# %% [markdown]
# # WEB

# %% [markdown]
# > **암호화**
#
# 단방향 : 암호화는 되는데 복호화가 되지 않음
#
# 양방향 : 암호화와 복호화가 둘 다 된다.

# %% [markdown]
# 1. 카카오 지도 사용 인증 키 (JavaScript API KEY) : addc8759f0742edef28f7435912ab906
